# %%
# import functions from external packages
import requests 
import bs4 as bs

# %%
# we creat nine lists to store the information we want to extract from GTD.
dates=[]
countries=[]
groups=[]
fatalities=[]
injured=[]
target_types=[]
regions=[]
attack_types=[]
weapon_types=[]
pages = [str(i) for i in range(1,1916)]  #modify the range according to the results
values = ['white','dark-gray']
for i in pages:
#     begin the crawling
    print('crawing page'+i)
    source = requests.get('https://www.start.umd.edu/gtd/search/Results.aspx?expanded=yes&casualties_type=&casualties_max=&success=yes&ob=GTDID&od=desc&page='+i+'&count=100')
#     find information from the webpage
    source.encoding = 'utf-8'
    soup = bs.BeautifulSoup(source.content , features='html.parser') 
    containers = soup.find_all('table', attrs={'class': 'results'})
    for table in containers:
        for v in values:
            for row in table.find_all('tr',attrs={'class': v}):
                date = row.select('td:nth-of-type(2)')[0].text
                print("date")
                print(date)
                dates.append(date)
            
            for row in table.find_all('tr',attrs={'class': v}):
                country = row.select('td:nth-of-type(3)')[0].text
                print("country")
                print(country)
                countries.append(country)
            for row in table.find_all('tr',attrs={'class': v}):
                group = row.select('td:nth-of-type(5)')[0].text
                print("group")
                print(group)
                groups.append(group)
            for row in table.find_all('tr',attrs={'class':v}):
                fatality = row.select('td:nth-of-type(6)')[0].text
                print("fatality")
                print(fatality)
                fatalities.append(fatality)
            for row in table.find_all('tr',attrs={'class': v}):
                injury = row.select('td:nth-of-type(7)')[0].text
                print("injury")
                print(injury)
                injured.append(injury)
            for row in table.find_all('tr',attrs={'class':v}):
                target = row.select('td:nth-of-type(8)')[0].text
                print("target")
                print(target)
                target_types.append(target)
            for row in table.find_all('tr',attrs={'class':v}):
                region = row.select('td:nth-of-type(9)')[0].text
                print("region")
                print(region)
                regions.append(region)
            for row in table.find_all('tr',attrs={'class':v}):
                attack = row.select('td:nth-of-type(10)')[0].text
                print("attack")
                print(attack)
                attack_types.append(attack)
            for row in table.find_all('tr',attrs={'class':v}):
                weapon = row.select('td:nth-of-type(11)')[0].text
                print("weapon")
                print(weapon)
                weapon_types.append(weapon)
# Out:
# crawing page1
# date
# 2018-12-31
# date
# 2018-12-31
# date
# 2018-12-31
# date
# 2018-12-31
# date
# 2018-12-31
# date
# 2018-12-31
# date
# 2018-12-31
# date
# 2018-12-31
# date
# 2018-12-31
# date
# 2018-12-31
# date
# 2018-12-31
# date
# 2018-12-31
# date
# 2018-12-30
# date
# 2018-12-30
# date
# 2018-12-30
# date
# 2018-12-30
# date
# 2018-12-30
# date
# 2018-12-30
# date
# 2018-12-30
# date
# 2018-12-30
# date
# 2018-12-30
# date
# 2018-12-30
# date
# 2018-12-29
# date
# 2018-12-29
# date
# 2018-12-29
# date
# 2018-12-29
# date
# 2018-12-29
# date
# 2018-12-29
# date
# 2018-12-28
# date
# 2018-12-29
# date
# 2018-12-29
# date
# 2018-12-29
# date
# 2018-12-29
# date
# 2018-12-28
# date
# 2018-12-28
# date
# 2018-12-28
# date
# 2018-12-28
# date
# 2018-12-28
# date
# 2018-12-28
# date
# 2018-12-28
# date
# 2018-12-28
# date
# 2018-12-28
# date
# 2018-12-28
# date
# 2018-12-28
# date
# 2018-12-28
# date
# 2018-12-28
# date
# 2018-12-28
# date
# 2018-12-28
# date
# 2018-12-28
# date
# 2018-12-27
# country
# Afghanistan
# country
# Afghanistan
# country
# Afghanistan
# country
# Libya
# country
# Pakistan
# country
# Pakistan
# country
# Yemen
# country
# India
# country
# Afghanistan
# country
# Afghanistan
# country
# Iraq
# country
# Philippines
# country
# Afghanistan
# country
# India
# country
# Nigeria
# country
# Yemen
# country
# Indonesia
# country
# India
# country
# India
# country
# Thailand
# country
# Democratic Republic of the Congo
# country
# Nigeria
# country
# Thailand
# country
# Afghanistan
# country
# Afghanistan
# country
# India
# country
# India
# country
# Afghanistan
# country
# Saudi Arabia
# country
# India
# country
# Thailand
# country
# Thailand
# country
# Thailand
# country
# Afghanistan
# country
# Nigeria
# country
# Philippines
# country
# Iraq
# country
# Israel
# country
# Yemen
# country
# Iraq
# country
# India
# country
# India
# country
# Thailand
# country
# Thailand
# country
# Thailand
# country
# Afghanistan
# country
# Philippines
# country
# Somalia
# country
# Thailand
# country
# Yemen
# group
# Taliban
# group
# Taliban
# group
# Unknown
# group
# Unknown
# group
# Khorasan Chapter of the Islamic State
# group
# Unknown
# group
# Unknown
# group
# Unknown
# group
# Taliban
# group
# Unknown
# group
# Islamic State of Iraq and the Levant (ISIL)
# group
# Bangsamoro Islamic Freedom Movement (BIFM),Maute Group
# group
# Taliban
# group
# Unknown
# group
# Fulani extremists
# group
# Houthi extremists (Ansar Allah)
# group
# Mujahidin Indonesia Timur (MIT)
# group
# Jaish-e-Mohammad (JeM)
# group
# Lashkar-e-Taiba (LeT)
# group
# Unknown
# group
# Kamwina Nsapu Militia
# group
# Boko Haram
# group
# Anti-Government extremists
# group
# Taliban
# group
# Taliban
# group
# Communist Party of India - Maoist (CPI-Maoist)
# group
# Communist Party of India - Maoist (CPI-Maoist)
# group
# Taliban
# group
# Houthi extremists (Ansar Allah)
# group
# Unknown
# group
# Unknown
# group
# Unknown
# group
# Unknown
# group
# Taliban
# group
# Boko Haram
# group
# Unknown
# group
# Kurdistan Workers' Party (PKK)
# group
# Unknown
# group
# Houthi extremists (Ansar Allah)
# group
# Islamic State of Iraq and the Levant (ISIL)
# group
# Unknown
# group
# Lashkar-e-Taiba (LeT)
# group
# Separatists (suspected)
# group
# Separatists (suspected)
# group
# Separatists (suspected)
# group
# Taliban
# group
# Bangsamoro Islamic Freedom Movement (BIFM) (suspected),Maute Group (suspected)
# group
# Al-Shabaab
# group
# Separatists (suspected)
# group
# Houthi extremists (Ansar Allah)
# fatality
# 1
# fatality
# Unknown
# fatality
# 1
# fatality
# 0
# fatality
# 3
# fatality
# 1
# fatality
# 0
# fatality
# 0
# fatality
# 10
# fatality
# 2
# fatality
# 2
# fatality
# 2
# fatality
# 1
# fatality
# 1
# fatality
# 2
# fatality
# 0
# fatality
# 1
# fatality
# 0
# fatality
# 0
# fatality
# 0
# fatality
# 1
# fatality
# Unknown
# fatality
# 1
# fatality
# 0
# fatality
# 1
# fatality
# 0
# fatality
# 0
# fatality
# 4
# fatality
# 0
# fatality
# 0
# fatality
# 0
# fatality
# 0
# fatality
# 0
# fatality
# 2
# fatality
# Unknown
# fatality
# 0
# fatality
# 5
# fatality
# 0
# fatality
# 17
# fatality
# Unknown
# fatality
# 0
# fatality
# 1
# fatality
# 0
# fatality
# 0
# fatality
# 0
# fatality
# Unknown
# fatality
# 0
# fatality
# Unknown
# fatality
# 0
# fatality
# 0
# injury
# 3
# injury
# Unknown
# injury
# 0
# injury
# 0
# injury
# 0
# injury
# 0
# injury
# 5
# injury
# 0
# injury
# 10
# injury
# 5
# injury
# 2
# injury
# 34
# injury
# 0
# injury
# 0
# injury
# 0
# injury
# 0
# injury
# 0
# injury
# 1
# injury
# 0
# injury
# 0
# injury
# 0
# injury
# Unknown
# injury
# 0
# injury
# 0
# injury
# 1
# injury
# 0
# injury
# 0
# injury
# 0
# injury
# 0
# injury
# 0
# injury
# 0
# injury
# 0
# injury
# 3
# injury
# Unknown
# injury
# Unknown
# injury
# 1
# injury
# 0
# injury
# 0
# injury
# 8
# injury
# Unknown
# injury
# 0
# injury
# 0
# injury
# 0
# injury
# 0
# injury
# 0
# injury
# Unknown
# injury
# 3
# injury
# Unknown
# injury
# 0
# injury
# 0
# target
# Police
# target
# Military
# target
# Government (General)
# target
# Utilities
# target
# Unknown
# target
# Business
# target
# Police
# target
# Military
# target
# Utilities
# target
# Business
# target
# Military
# target
# Business
# target
# Police
# target
# Government (General)
# target
# Private Citizens & Property
# target
# NGO
# target
# Business
# target
# Military
# target
# Government (General)
# target
# Utilities
# target
# Government (General)
# target
# Private Citizens & Property
# target
# Private Citizens & Property
# target
#
# group
# Unknown
# group
# Unknown
# group
# Unknown
# group
# Unknown
# group
# Fulani extremists
# group
# Houthi extremists (Ansar Allah)
# group
# Unknown
# group
# Unknown
# group
# Unknown
# group
# Unknown
# group
# Islamic State of Iraq and the Levant (ISIL)
# group
# Unknown
# group
# Taliban
# group
# Taliban
# group
# Communist Party of India - Maoist (CPI-Maoist)
# group
# Communist Party of India - Maoist (CPI-Maoist)
# group
# Communist Party of India - Maoist (CPI-Maoist)
# group
# Houthi extremists (Ansar Allah)
# group
# Al-Shabaab
# group
# Unknown
# group
# Unknown
# group
# Unknown
# group
# Unknown
# group
# Boko Haram
# group
# Unknown
# group
# Boko Haram
# group
# Unknown
# group
# Unknown
# group
# Unknown
# group
# Unknown
# group
# Islamic State of Iraq and the Levant (ISIL)
# group
# Separatists (suspected)
# group
# Separatists (suspected)
# group
# Separatists (suspected)
# group
# Separatists (suspected)
# group
# Al-Shabaab,Jabha East Africa
# group
# Ambazonia Defense Forces (ADF) (suspected)
# group
# Taliban
# group
# Hasam Movement
# fatality
# 0
# fatality
# 1
# fatality
# 8
# fatality
# 4
# fatality
# 0
# fatality
# 0
# fatality
# 0
# fatality
# 0
# fatality
# 10
# fatality
# 0
# fatality
# 2
# fatality
# 1
# fatality
# 0
# fatality
# 1
# fatality
# 2
# fatality
# 5
# fatality
# Unknown
# fatality
# 1
# fatality
# 0
# fatality
# 0
# fatality
# 3
# fatality
# 1
# fatality
# 0
# fatality
# 1
# fatality
# 2
# fatality
# 0
# fatality
# 0
# fatality
# 1
# fatality
# 0
# fatality
# 20
# fatality
# 0
# fatality
# 0
# fatality
# 0
# fatality
# 4
# fatality
# Unknown
# fatality
# 0
# fatality
# Unknown
# fatality
# 1
# fatality
# 0
# fatality
# 1
# fatality
# 1
# fatality
# 2
# fatality
# 0
# fatality
# 0
# fatality
# 0
# fatality
# 0
# fatality
# 0
# fatality
# 1
# fatality
# 6
# fatality
# 4
# injury
# 0
# injury
# 0
# injury
# 0
# injury
# 2
# injury
# 1
# injury
# 2
# injury
# 1
# injury
# 0
# injury
# 10
# injury
# 3
# injury
# 5
# injury
# 3
# injury
# 0
# injury
# 0
# injury
# 2
# injury
# 2
# injury
# Unknown
# injury
# 0
# injury
# 0
# injury
# 0
# injury
# 0
# injury
# 0
# injury
# 0
# injury
# 0
# injury
# 2
# injury
# 0
# injury
# 0
# injury
# 0
# injury
# 0
# injury
# Unknown
# injury
# 0
# injury
# 0
# injury
# 0
# injury
# 4
# injury
# Unknown
# injury
# 0
# injury
# Unknown
# injury
# 0
# injury
# 0
# injury
# 0
# injury
# 0
# injury
# Unknown
# injury
# 0
# injury
# 4
# injury
# 0
# injury
# 0
# injury
# 3
# injury
# 0
# injury
# 0
# injury
# 12
# target
# Private Citizens & Property
# target
# Private Citizens & Property
# target
# Police
# target
# Private Citizens & Property
# target
# Utilities
# target
# Police
# target
# Government (General)
# target
# Educational Institution
# target
# Utilities
# target
# Police,Transportation
# target
# Police,Police
# target
# Police
# target
# Utilities
# target
# Government (General)
# target
# Military
# target
# Private Citizens & Property
# target
# NGO
# target
# Government (General)
# target
# Police
# target
# Military
# target
# Unknown
# target
# Military
# target
# Transportation
# target
# Private Citizens & Property
# target
# Terrorists/Non-state Militia
# target
# Unknown
# target
# Private Citizens & Property
# target
# Government (General)
# target
# Private Citizens & Property
# target
# Military
# target
# Educational Institution
# target
# Transportation
# target
# Telecommunication
# target
# Military
# target
# Military
# target
# Violent Political Party
# target
# Military
# target
# Government (General)
# target
# Educational Institution
# target
# Violent Political Party
# target
# Journalists & Media
# target
# Police
# target
# Utilities
# target
# Private Citizens & Property
# target
# Utilities
# target
# Utilities
# target
# Government (General),Police
# target
# Military
# target
# Private Citizens & Property
# target
# Tourists,Tourists
# region
# Western Europe
# region
# South Asia
# region
# South Asia
# region
# Sub-Saharan Africa
# region
# Middle East & North Africa
# region
# Southeast Asia
# region
# Sub-Saharan Africa
# region
# Sub-Saharan Africa
# region
# South Asia
# region
# Western Europe
# region
# South Asia
# region
# South Asia
# region
# Middle East & North Africa
# region
# South Asia
# region
# Sub-Saharan Africa
# region
# Sub-Saharan Africa
# region
# Middle East & North Africa
# region
# North America
# region
# South Asia
# region
# South Asia
# region
# Sub-Saharan Africa
# region
# Middle East & North Africa
# region
# Southeast Asia
# region
# South Asia
# region
# South Asia
# region
# South Asia
# region
# South Asia
# region
# South Asia
# region
# Middle East & North Africa
# region
# Sub-Saharan Africa
# region
# South Asia
# region
# Southeast Asia
# region
# Southeast Asia
# region
# South Asia
# region
# Sub-Saharan Africa
# region
# South Asia
# region
# Sub-Saharan Africa
# region
# Sub-Saharan Africa
# region
# Middle East & North Africa
# region
# South Asia
# region
# Southeast Asia
# region
# Middle East & North Africa
# region
# Southeast Asia
# region
# Southeast Asia
# region
# Southeast Asia
# region
# Southeast Asia
# region
# Sub-Saharan Africa
# region
# Sub-Saharan Africa
# region
# South Asia
# region
# Middle East & North Africa
# attack
# Facility/Infrastructure Attack
# attack
# Unknown
# attack
# Facility/Infrastructure Attack
# attack
# Armed Assault
# attack
# Hostage Taking (Barricade Incident),Facility/Infrastructure Attack
# attack
# Armed Assault
# attack
# Assassination
# attack
# Facility/Infrastructure Attack
# attack
# Armed Assault
# attack
# Armed Assault
# attack
# Armed Assault
# attack
# Assassination
# attack
# Bombing/Explosion
# attack
# Armed Assault
# attack
# Armed Assault
# attack
# Armed Assault
# attack
# Hostage Taking (Kidnapping)
# attack
# Assassination
# attack
# Armed Assault
# attack
# Armed Assault
# attack
# Bombing/Explosion
# attack
# Armed Assault
# attack
# Bombing/Explosion
# attack
# Hostage Taking (Kidnapping)
# attack
# Unknown
# attack
# Bombing/Explosion
# attack
# Bombing/Explosion
# attack
# Bombing/Explosion,Armed Assault
# attack
# Bombing/Explosion
# attack
# Armed Assault,Facility/Infrastructure Attack
# attack
# Facility/Infrastructure Attack
# attack
# Bombing/Explosion
# attack
# Bombing/Explosion
# attack
# Unknown
# attack
# Unknown
# attack
# Facility/Infrastructure Attack
# attack
# Armed Assault
# attack
# Assassination
# attack
# Bombing/Explosion
# attack
# Assassination
# attack
# Assassination
# attack
# Facility/Infrastructure Attack
# attack
# Bombing/Explosion
# attack
# Bombing/Explosion
# attack
# Bombing/Explosion
# attack
# Bombing/Explosion
# attack
# Bombing/Explosion
# attack
# Hostage Taking (Kidnapping)
# attack
# Bombing/Explosion
# attack
# Bombing/Explosion
# weapon
# Melee
# weapon
# Unknown
# weapon
# Incendiary,Unknown
# weapon
# Firearms
# weapon
# Firearms
# weapon
# Explosives/Bombs/Dynamite,Firearms
# weapon
# Firearms
# weapon
# Incendiary
# weapon
# Firearms
# weapon
# Melee
# weapon
# Firearms
# weapon
# Explosives/Bombs/Dynamite
# weapon
# Explosives/Bombs/Dynamite
# weapon
# Firearms
# weapon
# Firearms
# weapon
# Firearms
# weapon
# Unknown
# weapon
# Firearms
# weapon
# Firearms
# weapon
# Firearms
# weapon
# Explosives/Bombs/Dynamite
# weapon
# Firearms
# weapon
# Explosives/Bombs/Dynamite
# weapon
# Unknown
# weapon
# Unknown
# weapon
# Explosives/Bombs/Dynamite
# weapon
# Explosives/Bombs/Dynamite
# weapon
# Explosives/Bombs/Dynamite,Firearms
# weapon
# Explosives/Bombs/Dynamite
# weapon
# Firearms
# weapon
# Incendiary
# weapon
# Explosives/Bombs/Dynamite
# weapon
# Explosives/Bombs/Dynamite
# weapon
# Unknown
# weapon
# Unknown
# weapon
# Incendiary
# weapon
# Firearms
# weapon
# Firearms
# weapon
# Explosives/Bombs/Dynamite
# weapon
# Firearms
# weapon
# Firearms
# weapon
# Incendiary,Unknown
# weapon
# Explosives/Bombs/Dynamite
# weapon
# Explosives/Bombs/Dynamite
# weapon
# Explosives/Bombs/Dynamite
# weapon
# Explosives/Bombs/Dynamite
# weapon
# Explosives/Bombs/Dynamite
# weapon
# Melee
# weapon
# Explosives/Bombs/Dynamite
# weapon
# Explosives/Bombs/Dynamite
# crawing page2

# %%
len(dates)

# %%
groups

# %%
fatalities

# %%
injured

# %%
target_types

# %%
regions

# %%
attack_types

# %%
weapon_types

# %%
# build a dict data structure called dictionary
dictionary = {
    'dates': dates,
    'countries': countries,
    'groups': groups,
    'fatalities': fatalities,
    'injured': injured,
    'target_types': target_types,
    'regions': regions,
    'regions': regions,
    'attack_types': attack_types,
    'weapon_types': weapon_types}
  
dictionary

# %%
# insert the dictionary into a data structure called dataframe 
import pandas as pd
df = pd.DataFrame.from_dict(dictionary, orient ='index').transpose()
df.to_csv('GTD.csv')
df
